# %%
import numpy as np
import matplotlib.pyplot as plt
from EULER import *

# %%
#parámetros de simulación
g = 9.8
angulo = 45*np.pi/180
vo = 15*np.sin(angulo) #velocidad inicial en el eje y 
yo = 0 #altura inicial
tmax = 2*vo/g#tiempo final
tmin = 0#tiempo inicial
h = 0.001 #tamaño del paso
f_xy = '(-9.8)' #función aceleración para modelo lineal de arrastre
evaluar_1 = euler_mejorado() ## algoritmo de euler mejorado 
x_y_1 = np.array(evaluar_1.euler_2do_m(f_xy,tmax,tmin,h,yo,vo))
t1 = x_y_1[0,:]
y1 = x_y_1[1,:]
v1 = x_y_1[2,:]
x1 = 15*np.cos(angulo)*t1
plt.figure(1)
yl, = plt.plot(t1,y1, label ='posicion en y ')
xl, = plt.plot(t1,x1,label = 'posicion en x')

plt.ylabel('Distancia[m]')
plt.xlabel('Tiempo[s]')
plt.title('Distancia vs Tiempo ')
plt.grid('true')
plt.legend(handles=[yl,xl])
plt.show()
xmax = ((15**2)/g)
print('Xmaximo teorico = ', xmax, ',x_numerico = ',x1[-1])
# Out:
# /home/roberto/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# Xmaximo teorico =  22.959183673469386 ,x_numerico =  22.959183673469383

# %%
#%%
plt.figure(2)
xy, = plt.plot(x1,y1, label =' ')
plt.ylabel('y[m]')
plt.xlabel('x[m]')
plt.title('y vs x ')
plt.grid('on')
plt.legend(handles=[xy])
plt.show()

# %% [markdown]
# Se busca analizar el $X$ vs $\theta$, la ecuación cuadrática que modela este comportamiento es:
# \begin{equation}
# x^{2}-k\sin{(\theta)}\cos{(\theta)}-k\cos^{2}{(\theta)}h=0
# \end{equation}
# Con $k=\frac{2v^{2}}{g}$
# \begin{equation*}
# \end{equation*}
# Las soluciones respectivas son:
# \begin{equation}
# x_{1}=\frac{1}{2}\cos{(\theta)}\left(k\sin{(\theta)}-\sqrt{k}\sqrt{4h+k\sin^{2}{(\theta)}}\right)
# \end{equation}
#
#
# \begin{equation}
# x_{2}=\frac{1}{2}\cos{(\theta)}\left(k\sin{(\theta)}+\sqrt{k}\sqrt{4h+k\sin^{2}{(\theta)}}\right)
# \end{equation}

# %% [markdown]
# La ecuación anterior modela $X$ vs $\theta$ para cualquier $h$.

# %%
theta = np.linspace(0,90,5000)*(np.pi/180) # vector de theta en radianes
v_ = 5000
h = 100 # altura inicial
k = 2*(v_)**2/g
x_ = (1/2)*np.cos(theta)*((((k)**0.5)*(4*h+k*(np.sin(theta))**2)**0.5)+k*np.sin(theta))
x_1 = (1/2)*np.cos(theta)*(-(((k)**0.5)*(4*h+k*(np.sin(theta))**2)**0.5)+k*np.sin(theta))
argu_x = np.argmax(x_) #argumento del elemento máximo en x
print('Altura Inicial = ', h)
print('v inicial = ', v_)
print('Angulo para Xmax = ', theta[argu_x]*180/np.pi)
plt.plot(theta*180/np.pi,x_)
plt.plot(theta*180/np.pi,x_1)
plt.ylabel('X')
plt.xlabel(r'$\theta$')
plt.grid('on')
# Out:
# Altura Inicial =  100
# v inicial =  5000
# Angulo para Xmax =  44.99099819963993

# %% [markdown]
# La solución $x_{1}$ no tiene sentído físico, entonces se desprecia, y se procede a realizar el cálculo de la dependencia de la velocidad para el ángulo para la distancia max

# %%
from sympy import *

# %%
x = symbols('x')
init_printing(use_unicode=True)
1/2*diff(cos(x)*(((k**0.5)*(4*h+k*(sin(x))**2)**0.5)+k*sin(x)), x)
# Out:
#     ⎛                                               -0.5
#     ⎜                 ⎛                    2       ⎞
# 0.5⋅⎝11.5243354962405⋅⎝5.10204081632653⋅sin (x) + 8⎠    ⋅sin(x)⋅cos(x) + 5.102
#
#                   ⎞              ⎛
#                   ⎟              ⎜                 ⎛                    2
# 04081632653⋅cos(x)⎠⋅cos(x) - 0.5⋅⎝2.25876975726313⋅⎝5.10204081632653⋅sin (x) +
#
#    0.5                          ⎞
#   ⎞                             ⎟
#  8⎠    + 5.10204081632653⋅sin(x)⎠⋅sin(x)

# %% [markdown]
# una completa locura..., usando wolfram, se obtiene algo más interesante:

# %% [markdown]
# En este caso Dist = x, y la variable independiente es x (theta)
# $\frac{d Dist}{d x} = cos^2(x) ((0.5 k^{1.5} sin(x))/(4 h + k sin^2(x))^{0.5} + 0.5 k) + sin(x) (-0.5 (k (4 h + k sin^2(x)))^{0.5} - 0.5 k sin(x))$

# %% [markdown]
# El máximo de esta función se da para :
# $\theta= cos^{-1}\left(\frac{\sqrt{(4 h + k)}}{\sqrt{(2)} \sqrt{(2 h + k)}}\right)$

# %%
cos_theta_max = (((4*h+k)**0.5)/(((2)**0.5)*(2*h+k)**0.5))
theta_max = np.arccos(cos_theta_max)
print('Altura Inicial = ', h)
print('v inicial = ', v_)
print('Angulo para Xmax(numeric) = ', theta[argu_x]*180/np.pi)
print('Angulo de Xmax(analitico) = ',(theta_max*180/np.pi))
# Out:
# Altura Inicial =  100
# v inicial =  5000
# Angulo para Xmax(numeric) =  44.99099819963993
# Angulo de Xmax(analitico) =  44.99887704674103

# %% [markdown]
# Cuando $\lim_{k\rightarrow \infty} \frac{\sqrt{4 h + k}}{\sqrt{2} \sqrt{2 h + k}}= \frac{1}{\sqrt{2}} $

# %% [markdown]
# con esto se concluye que cuando $k \rightarrow \infty$, $\theta_{max} = 45°$, y cuando $k \rightarrow 0$ se obtiene una caida libre. MODELO GENERAL DE MOVIMIENTO PARABÓLICO

# %% [markdown]
# modelo ideal vs modelo con arrastre

# %%
#parámetros de simulación
g = 9.8
angulo = 33*np.pi/180
vo = 15*np.sin(angulo) #velocidad inicial en el eje y 
v_ini = 15
vo_x = v_ini*np.cos(angulo)
vo_y = v_ini*np.sin(angulo)
yo = 2 #altura inicial
xo = 0
tmax = 2*vo/g#tiempo final
tmin = 0#tiempo inicial
h = 0.001 #tamaño del paso

f_xy = '(9.8)*(-1)' #función aceleración ideal
f_xy_y = '(9.8)*(-1-0.1*(y))' #función aceleración para modelo lineal arrastre
f_xy_x = '-0.1*y'
evaluar_1 = euler_mejorado() ## algoritmo de euler mejorado 

x_y_1 = np.array(evaluar_1.euler_2do_m(f_xy,tmax,tmin,h,yo,vo))
y_ar = np.array(evaluar_1.euler_2do_m(f_xy_y,tmax,tmin,h,yo,vo_y))
x_ar = np.array(evaluar_1.euler_2do_m(f_xy_x,tmax,tmin,h,xo,vo_x))
t1 = x_y_1[0,:]
y1 = x_y_1[1,:]
v1 = x_y_1[2,:]

t_ar = y_ar[0,:]
y1_ar = y_ar[1,:]
x1_ar = x_ar[1,:]



x1 = 15*np.cos(angulo)*t1


ideal, = plt.plot(x1,y1, label ='IDEAL')
arrastre, = plt.plot(x1_ar,y1_ar, label = 'ARRASTRE')
plt.ylabel('y[m]')
plt.xlabel('x[m]')
plt.title('y vs x ')
plt.legend(handles=[ideal, arrastre])
plt.grid('on')
plt.ylim(0,10)
plt.show()
